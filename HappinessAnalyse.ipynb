# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmetondermu/Training_ErrorMetrics/blob/main/HappinessAnalyse.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('/content/drive/MyDrive/training/happiness.csv')

# %%
data.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
data.drop('Happiness Rank',axis=1, inplace=True)

# %%
data.drop('Region',axis=1, inplace=True)

# %%
data.tail()
# Out:
#      Country  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 153   Rwanda            3.465         0.03464                   0.22208
# 154    Benin            3.340         0.03656                   0.28665
# 155    Syria            3.006         0.05015                   0.66320
# 156  Burundi            2.905         0.08658                   0.01530
# 157     Togo            2.839         0.06727                   0.20868
#
#       Family  Health (Life Expectancy)  Freedom  \
# 153  0.77370                   0.42864  0.59201
# 154  0.35386                   0.31910  0.48450
# 155  0.47489                   0.72193  0.15684
# 156  0.41587                   0.22396  0.11850
# 157  0.13995                   0.28443  0.36453
#
#      Trust (Government Corruption)  Generosity  Dystopia Residual
# 153                        0.55191     0.22628            0.67042
# 154                        0.08010     0.18260            1.63328
# ...

# %%
data.dtypes
# Out:
# Country                           object
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
import seaborn as sns

# %%
sns.countplot(x='Country', data=data)
# Out:
# <Axes: xlabel='Country', ylabel='count'>

# %%
data.drop('Country',axis=1, inplace=True)
# hue argümanı görselde verilen değişkene göre gruplamayı sağlar

# %%
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
data.isnull().sum()
# Out:
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
X = data.drop("Happiness Score",axis=1)

# %%
y=data["Happiness Score"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=100)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.9999999453265149
